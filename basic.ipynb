# %%
from background.task.basic_tasks import add

# %%
result = add.delay(4,4)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\COM-NMOIM\miniforge3\envs\celery-note\Lib\site-packages\redis\connection.py:385, in AbstractConnection.connect_check_health(self, check_health)
#     384 try:
# --> 385     sock = self.retry.call_with_retry(
#     386         lambda: self._connect(), lambda error: self.disconnect(error)
#     387     )
#     388 except socket.timeout:
#
# File c:\Users\COM-NMOIM\miniforge3\envs\celery-note\Lib\site-packages\redis\retry.py:87, in Retry.call_with_retry(self, do, fail)
#      86 try:
# ---> 87     return do()
#      88 except self._supported_errors as error:
#
# File c:\Users\COM-NMOIM\miniforge3\envs\celery-note\Lib\site-packages\redis\connection.py:386, in AbstractConnection.connect_check_health.<locals>.<lambda>()
#     384 try:
#     385     sock = self.retry.call_with_retry(
# ...
